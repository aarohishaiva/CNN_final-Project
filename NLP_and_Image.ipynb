# %% [markdown]
# <a href="https://colab.research.google.com/github/aarohishaiva/CNN_final-Project/blob/main/NLP_and_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# First, install necessary libraries
# !pip install transformers gradio torch

import gradio as gr
from transformers import pipeline

# Load pretrained models for various tasks
summarizer = pipeline("summarization")
text_generator = pipeline("text-generation", model="gpt2")
sentiment_analyzer = pipeline("sentiment-analysis")
question_answerer = pipeline("question-answering")

# Define functions for each task

def summarize_text(text):
    summary = summarizer(text, max_length=50, min_length=25, do_sample=False)
    return summary[0]['summary_text']

def next_word_prediction(text, max_length=50):
    completion = text_generator(text, max_length=max_length, num_return_sequences=1)
    return completion[0]['generated_text']

def analyze_sentiment(text):
    result = sentiment_analyzer(text)
    return result[0]['label']

def answer_question(context, question):
    result = question_answerer(question=question, context=context)
    return result['answer']

def generate_image(prompt):
    # Note: Replace this with actual image generation logic if needed
    return "Image generation feature is a placeholder."

# Define a single function to handle all tasks
def process_request(task, *args):
    if task == "Summarize Text":
        return summarize_text(args[0])
    elif task == "Next Word Prediction":
        return next_word_prediction(args[0], args[1])
    elif task == "Sentiment Analysis":
        return analyze_sentiment(args[0])
    elif task == "Question Answering":
        return answer_question(args[0], args[1])
    elif task == "Image Generation":
        return generate_image(args[0])

# Define Gradio interface with a dropdown for task selection
with gr.Blocks() as demo:
    task_dropdown = gr.Dropdown(
        choices=["Summarize Text", "Next Word Prediction", "Sentiment Analysis", "Question Answering", "Image Generation"],
        value="Summarize Text",
        label="Select Task"
    )

    # Input and output components
    input_components = [
        gr.Textbox(lines=10, placeholder="Enter text to summarize", label="Summarize Text", visible=True),
        gr.Textbox(lines=2, placeholder="Enter text", label="Next Word Prediction Text", visible=False),
        gr.Slider(minimum=10, maximum=100, value=50, label="Next Word Prediction Length", visible=False),
        gr.Textbox(lines=2, placeholder="Enter text to analyze sentiment", label="Sentiment Analysis Text", visible=False),
        gr.Textbox(lines=10, placeholder="Enter context", label="Question Answering Context", visible=False),
        gr.Textbox(lines=2, placeholder="Enter question", label="Question Answering Question", visible=False),
        gr.Textbox(lines=2, placeholder="Enter image generation prompt", label="Image Generation Prompt", visible=False)
    ]

    output_components = [
        gr.Textbox(label="Output")
    ]

    # Function to update input component visibility based on selected task
    def update_visibility(task):
        visibilities = [False] * len(input_components)
        if task == "Summarize Text":
            visibilities[0] = True
        elif task == "Next Word Prediction":
            visibilities[1] = visibilities[2] = True
        elif task == "Sentiment Analysis":
            visibilities[3] = True
        elif task == "Question Answering":
            visibilities[4] = visibilities[5] = True
        elif task == "Image Generation":
            visibilities[6] = True
        return {component: visible for component, visible in zip(input_components, visibilities)}
# Event listener for task selection
    task_dropdown.change(fn=update_visibility)
# Out:
# ...
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...

# %%
# First, install necessary libraries
# !pip install transformers gradio torch

import gradio as gr
from transformers import pipeline

# Load pretrained models for various tasks
summarizer = pipeline("summarization")
text_generator = pipeline("text-generation", model="gpt2")
sentiment_analyzer = pipeline("sentiment-analysis")
question_answerer = pipeline("question-answering")

# Define functions for each task

def summarize_text(text):
    summary = summarizer(text, max_length=50, min_length=25, do_sample=False)
    return summary[0]['summary_text']

def next_word_prediction(text, max_length=50):
    completion = text_generator(text, max_length=max_length, num_return_sequences=1)
    return completion[0]['generated_text']

def analyze_sentiment(text):
    result = sentiment_analyzer(text)
    return result[0]['label']

def answer_question(context, question):
    result = question_answerer(question=question, context=context)
    return result['answer']

def generate_image(prompt):
    # Note: Replace this with actual image generation logic if needed
    return "Image generation feature is a placeholder."

# Define a single function to handle all tasks
def process_request(task, *args):
    if task == "Summarize Text":
        return summarize_text(args[0])
    elif task == "Next Word Prediction":
        return next_word_prediction(args[0], args[1])
    elif task == "Sentiment Analysis":
        return analyze_sentiment(args[0])
    elif task == "Question Answering":
        return answer_question(args[0], args[1])
    elif task == "Image Generation":
        return generate_image(args[0])

# Define Gradio interface with a dropdown for task selection
iface = gr.Interface(
    fn=process_request,
    inputs=[
        gr.Dropdown(
            choices=["Summarize Text", "Next Word Prediction", "Sentiment Analysis", "Question Answering", "Image Generation"],
            label="Select Task",
            # Remove 'default' parameter and set the value directly in the choices list
            value="Summarize Text",
            key="task"
        ),
        gr.Textbox(lines=10, placeholder="Enter text to summarize", label="Summarize Text", key="arg1"),
        gr.Textbox(lines=2, placeholder="Enter text", label="Next Word Prediction Text", key="arg1"),
        gr.Slider(minimum=10, maximum=100, label="Next Word Prediction Length", key="arg2"),
        gr.Textbox(lines=2, placeholder="Enter text to analyze sentiment", label="Sentiment Analysis Text", key="arg1"),
        gr.Textbox(lines=10, placeholder="Enter context", label="Question Answering Context", key="arg1"),
        gr.Textbox(lines=2, placeholder="Enter question", label="Question Answering Question", key="arg2"),
        gr.Textbox(lines=2, placeholder="Enter image generation prompt", label="Image Generation Prompt", key="arg1")
    ],
    outputs=gr.Textbox(label="Output"),
    title="Multifunctional NLP and Image Generation Tool",
    description="Select a task and provide the necessary input. The tool will process your request using pretrained Hugging Face models."
)

# Launch the interface
iface.launch()
# Out:
# ...
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
